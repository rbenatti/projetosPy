# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='cp1252'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordlist)
# Out:
# 235886

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
len(wordclean)
# Out:
# 235886

# %%
wordclean[:20]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac']

# %%
# criar uma lista com valores unicos(set())
wordunique = list(set(wordclean))

# %%
# ordenar a lista
wordunique.sort()

# %%
#comntar a lista de palavras unicas
len(wordunique)
# Out:
# 234371

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %% [markdown]
# # Comprehensions

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words','r')])))

# %% [markdown]
# # Poderia ainda haver um filtro
# ```
# wordclean = sorted(list(set([word.strip().lower() for word in open('words','r') if condition(word)])))
# ```

# %%
wordclean[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
len(wordclean)
# Out:
# 234371

# %%
''.join(['a','b','c'])
# Out:
# 'abc'

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
signature('roma')
# Out:
# 'amor'

# %%
def anagram(myword):
    return [word for word in wordclean if signature(word) == signature(myword)]

# %%
anagram('amor')
# Out:
# ['amor', 'maro', 'mora', 'omar', 'roam']

# %%
# %timeit anagram('dictionary')
# Out:
# 358 ms ± 3.99 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# criando um dict
words_bysig = {}

# %%
for word in wordclean:
    signature(word)

# %%
import collections

# %%
words_bysig = collections.defaultdict(list)

for word in wordclean:
    words_bysig[signature(word)].append(word)

# %%
words_bysig
# Out:
# defaultdict(list,
#             {'a': ['a'],
#              'aa': ['aa'],
#              'aal': ['aal', 'ala'],
#              'aaiil': ['aalii'],
#              'aam': ['aam', 'ama'],
#              'aain': ['aani'],
#              'aaadkrrv': ['aardvark'],
#              'aadflorw': ['aardwolf'],
#              'aanor': ['aaron'],
#              'aacinor': ['aaronic', 'nicarao', 'ocarina'],
#              'aaacilnor': ['aaronical'],
#              'aaeinort': ['aaronite', 'aeration'],
#              'aaciinort': ['aaronitic'],
#              'aaru': ['aaru', 'aura'],
#              'ab': ['ab', 'ba'],
#              'aab': ['aba', 'baa'],
#              'aabbdeh': ['ababdeh'],
#              'aaabbu': ['ababua'],
#              'aabc': ['abac', 'caba'],
#              'aaabc': ['abaca'],
#              'aaabcet': ['abacate'],
#              'aaabcy': ['abacay'],
#              'aaabceint': ['abacinate'],
#              'aaabciinnot': ['abacination'],
# ...

# %%
def anagram_fast(myword):
    return words_bysig[signature(myword)]

# %%
anagram_fast('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
# %timeit anagram_fast('dictionary')
# Out:
# 839 ns ± 65.9 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
len(words_bysig)
# Out:
# 215843

# %%
ana_minus = {word: anagram_fast(word) for word in wordlist if len(anagram_fast(word)) < 1}

# %% [markdown]
# ana_minus

# %%
len(ana_minus)
# Out:
# 235886

# %%
type(ana_minus)
# Out:
# dict

# %%
ana_minus
# Out:
# {'A\n': [],
#  'a\n': [],
#  'aa\n': [],
#  'aal\n': [],
#  'aalii\n': [],
#  'aam\n': [],
#  'Aani\n': [],
#  'aardvark\n': [],
#  'aardwolf\n': [],
#  'Aaron\n': [],
#  'Aaronic\n': [],
#  'Aaronical\n': [],
#  'Aaronite\n': [],
#  'Aaronitic\n': [],
#  'Aaru\n': [],
#  'Ab\n': [],
#  'aba\n': [],
#  'Ababdeh\n': [],
#  'Ababua\n': [],
#  'abac\n': [],
#  'abaca\n': [],
#  'abacate\n': [],
#  'abacay\n': [],
#  'abacinate\n': [],
#  'abacination\n': [],
#  'abaciscus\n': [],
#  'abacist\n': [],
#  'aback\n': [],
#  'abactinal\n': [],
#  'abactinally\n': [],
#  'abaction\n': [],
#  'abactor\n': [],
#  'abaculus\n': [],
#  'abacus\n': [],
#  'Abadite\n': [],
#  'abaff\n': [],
#  'abaft\n': [],
#  'abaisance\n': [],
#  'abaiser\n': [],
#  'abaissed\n': [],
#  'abalienate\n': [],
#  'abalienation\n': [],
#  'abalone\n': [],
#  'Abama\n': [],
#  'abampere\n': [],
#  'abandon\n': [],
#  'abandonable\n': [],
#  'abandoned\n': [],
#  'abandonedly\n': [],
#  'abandonee\n': [],
# ...

# %%
type(anagram_fast('ricardo'))
# Out:
# list

# %%
ana_eq_one = {word: anagram_fast(word) for word in wordlist if len(anagram_fast(word)) < 2}

# %%
len(ana_eq_one)
# Out:
# 235886
