# %%
import pandas as pd
import requests

# %%
caminho = 'https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome'
resposta = requests.get(caminho)

# %%
resposta.status_code
# Out:
# 200

# %%
resposta.text
# Out:
# '{"dados":[{"id":204554,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204554","nome":"ABÍLIO SANTANA","siglaPartido":"PL","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37906","siglaUf":"BA","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204554.jpg","email":"dep.abiliosantana@camara.leg.br"},{"id":204521,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204521","nome":"ABOU ANNI","siglaPartido":"PSL","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36837","siglaUf":"SP","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204521.jpg","email":"dep.abouanni@camara.leg.br"},{"id":204379,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204379","nome":"ACÁCIO FAVACHO","siglaPartido":"PROS","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36763","siglaUf":"AP","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204379.j
# ...

# %%
df = pd.DataFrame(resposta.json()['dados'])

# %%
df
# Out:
#                                      email      id  idLegislatura  \
# 0          dep.abiliosantana@camara.leg.br  204554             56
# 1               dep.abouanni@camara.leg.br  204521             56
# 2          dep.acaciofavacho@camara.leg.br  204379             56
# 3            dep.adolfoviana@camara.leg.br  204560             56
# 4         dep.adrianaventura@camara.leg.br  204528             56
# 5         dep.adrianodobaldy@camara.leg.br  121948             56
# 6             dep.aecioneves@camara.leg.br   74646             56
# 7         dep.afonsoflorence@camara.leg.br  160508             56
# 8             dep.afonsohamm@camara.leg.br  136811             56
# 9            dep.afonsomotta@camara.leg.br  178835             56
# 10      dep.aguinaldoribeiro@camara.leg.br  160527             56
# 11         dep.airtonfaleiro@camara.leg.br  204495             56
# 12         dep.ajalbuquerque@camara.leg.br  204549             56
# ...

# %%
df_email = df[['id','email']]

# %%
df_email.head(15)
# Out:
#         id                               email
# 0   204554     dep.abiliosantana@camara.leg.br
# 1   204521          dep.abouanni@camara.leg.br
# 2   204379     dep.acaciofavacho@camara.leg.br
# 3   204560       dep.adolfoviana@camara.leg.br
# 4   204528    dep.adrianaventura@camara.leg.br
# 5   121948    dep.adrianodobaldy@camara.leg.br
# 6    74646        dep.aecioneves@camara.leg.br
# 7   160508    dep.afonsoflorence@camara.leg.br
# 8   136811        dep.afonsohamm@camara.leg.br
# 9   178835       dep.afonsomotta@camara.leg.br
# 10  160527  dep.aguinaldoribeiro@camara.leg.br
# 11  204495     dep.airtonfaleiro@camara.leg.br
# 12  204549     dep.ajalbuquerque@camara.leg.br
# 13  178836          dep.alanrick@camara.leg.br
# 14  160559      dep.alceumoreira@camara.leg.br

# %%
df_email.to_csv('C:/Users/ricardo.benatti.GOV/dataset/csv/list_email_senadores.csv', sep=';', encoding='cp1252', columns=['id','email'], doublequote=True,quoting=True, quotechar='"')

# %%
df.to_csv('C:/Users/ricardo.benatti.GOV/dataset/csv/list_senadores.csv', sep=';', encoding='cp1252', doublequote=True,quoting=True, quotechar='"')

# %%
df.tail()
# Out:
#                             email      id  idLegislatura         nome  \
# 508    dep.zecarlos@camara.leg.br  178889             56    ZÉ CARLOS
# 509      dep.zeneto@camara.leg.br  204559             56      ZÉ NETO
# 510     dep.zesilva@camara.leg.br  160632             56     ZÉ SILVA
# 511     dep.zevitor@camara.leg.br  204517             56     ZÉ VITOR
# 512  dep.zecadirceu@camara.leg.br  160592             56  ZECA DIRCEU
#
#       siglaPartido siglaUf                                                uri  \
# 508             PT      MA  https://dadosabertos.camara.leg.br/api/v2/depu...
# 509             PT      BA  https://dadosabertos.camara.leg.br/api/v2/depu...
# 510  SOLIDARIEDADE      MG  https://dadosabertos.camara.leg.br/api/v2/depu...
# 511             PL      MG  https://dadosabertos.camara.leg.br/api/v2/depu...
# 512             PT      PR  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                                             uriPartido  \
# ...

# %%
# %matplotlib notebook
df_email.head(10).plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook

# %%
from IPython.display import set_matplotlib_formats

# %%
set_matplotlib_formats('pdf', 'svg')

# %%
df_email.sample(15).to_frame()

# %%
df.dtypes

# %%
df_email.head(10).plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
set_matplotlib_formats(save=True)

# %%
df_email.head(10).plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
df['nome'].to_frame()

# %%
df['email']

# %%
df['email'].count()

# %%
df['siglaPartido'].value_counts()

# %%
df['siglaPartido'].value_counts().to_frame()

# %%
df.iloc[0,0]

# %%
df.iloc[0]

# %%
df.iloc[1]

# %%
df.iloc[511]

# %%
df.tail(1)

# %%
df.iloc[[0,1,2,511]]

# %%
df.iloc[[0,3]]

# %%
lista = range(500,512)

# %%
type(lista)
print(lista)

# %%
list(lista)

# %%
df.iloc[lista]

# %%
df.loc[0]

# %%
df.sample(5)
# Out:
#                                email      id  idLegislatura            nome  \
# 475   dep.tadeualencar@camara.leg.br  178922             56   TADEU ALENCAR
# 302  dep.lucasgonzalez@camara.leg.br  204523             56  LUCAS GONZALEZ
# 1         dep.abouanni@camara.leg.br  204521             56       ABOU ANNI
# 133      dep.dr.jaziel@camara.leg.br  204481             56      DR. JAZIEL
# 59        dep.biakicis@camara.leg.br  204374             56       BIA KICIS
#
#     siglaPartido siglaUf                                                uri  \
# 475          PSB      PE  https://dadosabertos.camara.leg.br/api/v2/depu...
# 302         NOVO      MG  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1            PSL      SP  https://dadosabertos.camara.leg.br/api/v2/depu...
# 133           PL      CE  https://dadosabertos.camara.leg.br/api/v2/depu...
# 59           PSL      DF  https://dadosabertos.camara.leg.br/api/v2/depu...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 9 columns):
# email            513 non-null object
# id               513 non-null int64
# idLegislatura    513 non-null int64
# nome             513 non-null object
# siglaPartido     513 non-null object
# siglaUf          513 non-null object
# uri              513 non-null object
# uriPartido       513 non-null object
# urlFoto          513 non-null object
# dtypes: int64(2), object(7)
# memory usage: 36.1+ KB

# %%
    df.sample(5).plot.bar(x='siglaUf',y='idLegislatura')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)
ax = df.plot.bar(rot=0)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
