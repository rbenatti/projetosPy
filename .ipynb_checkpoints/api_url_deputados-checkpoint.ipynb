# %%
import pandas as pd
import requests

# %%
caminho = 'https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome'
resposta = requests.get(caminho)

# %%
resposta.status_code
# Out:
# 200

# %%
resposta.url
# Out:
# u'https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome'

# %%
df = pd.DataFrame(resposta.json()['dados'])

# %%
df
# Out:
#                                      email      id  idLegislatura  \
# 0          dep.abiliosantana@camara.leg.br  204554             56
# 1               dep.abouanni@camara.leg.br  204521             56
# 2          dep.acaciofavacho@camara.leg.br  204379             56
# 3            dep.adolfoviana@camara.leg.br  204560             56
# 4         dep.adrianaventura@camara.leg.br  204528             56
# 5         dep.adrianodobaldy@camara.leg.br  121948             56
# 6             dep.aecioneves@camara.leg.br   74646             56
# 7         dep.afonsoflorence@camara.leg.br  160508             56
# 8             dep.afonsohamm@camara.leg.br  136811             56
# 9            dep.afonsomotta@camara.leg.br  178835             56
# 10      dep.aguinaldoribeiro@camara.leg.br  160527             56
# 11         dep.airtonfaleiro@camara.leg.br  204495             56
# 12         dep.ajalbuquerque@camara.leg.br  204549             56
# ...

# %%
df_email = df['email']

# %%
df_email
# Out:
# 0            dep.abiliosantana@camara.leg.br
# 1                 dep.abouanni@camara.leg.br
# 2            dep.acaciofavacho@camara.leg.br
# 3              dep.adolfoviana@camara.leg.br
# 4           dep.adrianaventura@camara.leg.br
# 5           dep.adrianodobaldy@camara.leg.br
# 6               dep.aecioneves@camara.leg.br
# 7           dep.afonsoflorence@camara.leg.br
# 8               dep.afonsohamm@camara.leg.br
# 9              dep.afonsomotta@camara.leg.br
# 10        dep.aguinaldoribeiro@camara.leg.br
# 11           dep.airtonfaleiro@camara.leg.br
# 12           dep.ajalbuquerque@camara.leg.br
# 13                dep.alanrick@camara.leg.br
# 14            dep.alceumoreira@camara.leg.br
# 15        dep.alcidesrodrigues@camara.leg.br
# 16                dep.alesilva@camara.leg.br
# 17     dep.alencarsantanabraga@camara.leg.br
# 18         dep.alessandromolon@camara.leg.br
# 19             dep.alexmanente@camara.leg.br
# 20             dep.alexsantana@camara.leg.br
# ...

# %%
df_email.shape
# Out:
# (513L,)

# %%
df_email.
# Out:
# <bound method Series.clip of 0            dep.abiliosantana@camara.leg.br
# 1                 dep.abouanni@camara.leg.br
# 2            dep.acaciofavacho@camara.leg.br
# 3              dep.adolfoviana@camara.leg.br
# 4           dep.adrianaventura@camara.leg.br
# 5           dep.adrianodobaldy@camara.leg.br
# 6               dep.aecioneves@camara.leg.br
# 7           dep.afonsoflorence@camara.leg.br
# 8               dep.afonsohamm@camara.leg.br
# 9              dep.afonsomotta@camara.leg.br
# 10        dep.aguinaldoribeiro@camara.leg.br
# 11           dep.airtonfaleiro@camara.leg.br
# 12           dep.ajalbuquerque@camara.leg.br
# 13                dep.alanrick@camara.leg.br
# 14            dep.alceumoreira@camara.leg.br
# 15        dep.alcidesrodrigues@camara.leg.br
# 16                dep.alesilva@camara.leg.br
# 17     dep.alencarsantanabraga@camara.leg.br
# 18         dep.alessandromolon@camara.leg.br
# 19             dep.alexmanente@camara.leg.br
# ...

# %%
df_email.to_csv('C:/Users/ricardo.benatti.GOV/dataset/csv/list_email_senadores.csv', sep=';', header=['EMAIL'], encoding='utf-8', columns=['email'], doublequote=True,quoting=True, quotechar='"')

# %%
df_email.to_frame()
# Out:
#                                      email
# 0          dep.abiliosantana@camara.leg.br
# 1               dep.abouanni@camara.leg.br
# 2          dep.acaciofavacho@camara.leg.br
# 3            dep.adolfoviana@camara.leg.br
# 4         dep.adrianaventura@camara.leg.br
# 5         dep.adrianodobaldy@camara.leg.br
# 6             dep.aecioneves@camara.leg.br
# 7         dep.afonsoflorence@camara.leg.br
# 8             dep.afonsohamm@camara.leg.br
# 9            dep.afonsomotta@camara.leg.br
# 10      dep.aguinaldoribeiro@camara.leg.br
# 11         dep.airtonfaleiro@camara.leg.br
# 12         dep.ajalbuquerque@camara.leg.br
# 13              dep.alanrick@camara.leg.br
# 14          dep.alceumoreira@camara.leg.br
# 15      dep.alcidesrodrigues@camara.leg.br
# 16              dep.alesilva@camara.leg.br
# 17   dep.alencarsantanabraga@camara.leg.br
# 18       dep.alessandromolon@camara.leg.br
# 19           dep.alexmanente@camara.leg.br
# 20           dep.alexsantana@camara.leg.br
# ...

# %%
df.tail()
# Out:
#                             email      id  idLegislatura         nome  \
# 507    dep.zecarlos@camara.leg.br  178889             56    ZÉ CARLOS
# 508      dep.zeneto@camara.leg.br  204559             56      ZÉ NETO
# 509     dep.zesilva@camara.leg.br  160632             56     ZÉ SILVA
# 510     dep.zevitor@camara.leg.br  204517             56     ZÉ VITOR
# 511  dep.zecadirceu@camara.leg.br  160592             56  ZECA DIRCEU
#
#       siglaPartido siglaUf                                                uri  \
# 507             PT      MA  https://dadosabertos.camara.leg.br/api/v2/depu...
# 508             PT      BA  https://dadosabertos.camara.leg.br/api/v2/depu...
# 509  SOLIDARIEDADE      MG  https://dadosabertos.camara.leg.br/api/v2/depu...
# 510             PL      MG  https://dadosabertos.camara.leg.br/api/v2/depu...
# 511             PT      PR  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                                             uriPartido  \
# ...

# %%
df_email.to_frame()
# Out:
#                                      email
# 0          dep.abiliosantana@camara.leg.br
# 1               dep.abouanni@camara.leg.br
# 2          dep.acaciofavacho@camara.leg.br
# 3            dep.adolfoviana@camara.leg.br
# 4         dep.adrianaventura@camara.leg.br
# 5         dep.adrianodobaldy@camara.leg.br
# 6             dep.aecioneves@camara.leg.br
# 7         dep.afonsoflorence@camara.leg.br
# 8             dep.afonsohamm@camara.leg.br
# 9            dep.afonsomotta@camara.leg.br
# 10      dep.aguinaldoribeiro@camara.leg.br
# 11         dep.airtonfaleiro@camara.leg.br
# 12         dep.ajalbuquerque@camara.leg.br
# 13              dep.alanrick@camara.leg.br
# 14          dep.alceumoreira@camara.leg.br
# 15      dep.alcidesrodrigues@camara.leg.br
# 16              dep.alesilva@camara.leg.br
# 17   dep.alencarsantanabraga@camara.leg.br
# 18       dep.alessandromolon@camara.leg.br
# 19           dep.alexmanente@camara.leg.br
# 20           dep.alexsantana@camara.leg.br
# ...

# %%
df_email.sample(15).to_frame()
# Out:
#                                           email
# 494          dep.vicentinhojunior@camara.leg.br
# 195      dep.freianastacioribeiro@camara.leg.br
# 47                  dep.atilalira@camara.leg.br
# 203              dep.gervasiomaia@camara.leg.br
# 417  dep.professoradayanepimentel@camara.leg.br
# 46                  dep.atilalins@camara.leg.br
# 335              dep.marcioalvino@camara.leg.br
# 269               dep.josepriante@camara.leg.br
# 396               dep.pauloguedes@camara.leg.br
# 37               dep.andrejanones@camara.leg.br
# 507             dep.wolneyqueiroz@camara.leg.br
# 323              dep.majorfabiana@camara.leg.br
# 40           dep.arlindochinaglia@camara.leg.br
# 3                 dep.adolfoviana@camara.leg.br
# 340           dep.marcobertaiolli@camara.leg.br

# %%
df.dtypes
# Out:
# email            object
# id                int64
# idLegislatura     int64
# nome             object
# siglaPartido     object
# siglaUf          object
# uri              object
# uriPartido       object
# urlFoto          object
# dtype: object

# %%
df['nome'].to_frame()
# Out:
#                       nome
# 0           ABÍLIO SANTANA
# 1                ABOU ANNI
# 2           ACÁCIO FAVACHO
# 3             ADOLFO VIANA
# 4          ADRIANA VENTURA
# 5         ADRIANO DO BALDY
# 6              AÉCIO NEVES
# 7          AFONSO FLORENCE
# 8              AFONSO HAMM
# 9             AFONSO MOTTA
# 10       AGUINALDO RIBEIRO
# 11          AIRTON FALEIRO
# 12          AJ ALBUQUERQUE
# 13               ALAN RICK
# 14           ALCEU MOREIRA
# 15       ALCIDES RODRIGUES
# 16               ALÊ SILVA
# 17   ALENCAR SANTANA BRAGA
# 18        ALESSANDRO MOLON
# 19            ALEX MANENTE
# 20            ALEX SANTANA
# 21         ALEXANDRE FROTA
# 22         ALEXANDRE LEITE
# 23       ALEXANDRE PADILHA
# 24     ALEXANDRE SERFIOTIS
# 25         ALEXIS FONTEYNE
# 26          ALICE PORTUGAL
# 27           ALIEL MACHADO
# 28            ALINE GURGEL
# 29          ALINE SLEUTJES
# ..                     ...
# 483     TONINHO WANDSCHEER
# 484          TÚLIO GADÊLHA
# ...

# %%
df['email']
# Out:
# 0            dep.abiliosantana@camara.leg.br
# 1                 dep.abouanni@camara.leg.br
# 2            dep.acaciofavacho@camara.leg.br
# 3              dep.adolfoviana@camara.leg.br
# 4           dep.adrianaventura@camara.leg.br
# 5           dep.adrianodobaldy@camara.leg.br
# 6               dep.aecioneves@camara.leg.br
# 7           dep.afonsoflorence@camara.leg.br
# 8               dep.afonsohamm@camara.leg.br
# 9              dep.afonsomotta@camara.leg.br
# 10        dep.aguinaldoribeiro@camara.leg.br
# 11           dep.airtonfaleiro@camara.leg.br
# 12           dep.ajalbuquerque@camara.leg.br
# 13                dep.alanrick@camara.leg.br
# 14            dep.alceumoreira@camara.leg.br
# 15        dep.alcidesrodrigues@camara.leg.br
# 16                dep.alesilva@camara.leg.br
# 17     dep.alencarsantanabraga@camara.leg.br
# 18         dep.alessandromolon@camara.leg.br
# 19             dep.alexmanente@camara.leg.br
# 20             dep.alexsantana@camara.leg.br
# ...

# %%
df['email'].count()
# Out:
# 512

# %%
df['siglaPartido'].value_counts()
# Out:
# PSL              53
# PT               53
# PL               40
# PP               40
# PSD              37
# PSDB             33
# MDB              33
# REPUBLICANOS     32
# PSB              30
# PDT              28
# DEM              26
# SOLIDARIEDADE    14
# PTB              11
# PODE             11
# PROS             10
# PSOL             10
# PSC               9
# CIDADANIA         9
# NOVO              8
# PCdoB             8
# AVANTE            7
# PATRIOTA          5
# PV                4
# REDE              1
# Name: siglaPartido, dtype: int64

# %%
df['siglaPartido'].value_counts().to_frame()
# Out:
#                siglaPartido
# PSL                      53
# PT                       53
# PL                       40
# PP                       40
# PSD                      37
# PSDB                     33
# MDB                      33
# REPUBLICANOS             32
# PSB                      30
# PDT                      28
# DEM                      26
# SOLIDARIEDADE            14
# PTB                      12
# PODE                     11
# PROS                     10
# PSOL                     10
# PSC                       9
# CIDADANIA                 9
# NOVO                      8
# PCdoB                     8
# AVANTE                    7
# PATRIOTA                  5
# PV                        4
# REDE                      1

# %%
df.iloc[0,0]
# Out:
# u'dep.abiliosantana@camara.leg.br'

# %%
df.iloc[0]
# Out:
# email                              dep.abiliosantana@camara.leg.br
# id                                                          204554
# idLegislatura                                                   56
# nome                                                ABÍLIO SANTANA
# siglaPartido                                                    PL
# siglaUf                                                         BA
# uri              https://dadosabertos.camara.leg.br/api/v2/depu...
# uriPartido       https://dadosabertos.camara.leg.br/api/v2/part...
# urlFoto          https://www.camara.leg.br/internet/deputado/ba...
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# email                                   dep.abouanni@camara.leg.br
# id                                                          204521
# idLegislatura                                                   56
# nome                                                     ABOU ANNI
# siglaPartido                                                   PSL
# siglaUf                                                         SP
# uri              https://dadosabertos.camara.leg.br/api/v2/depu...
# uriPartido       https://dadosabertos.camara.leg.br/api/v2/part...
# urlFoto          https://www.camara.leg.br/internet/deputado/ba...
# Name: 1, dtype: object

# %%
df.iloc[511]
# Out:
# email                                    dep.zevitor@camara.leg.br
# id                                                          204517
# idLegislatura                                                   56
# nome                                                      ZÉ VITOR
# siglaPartido                                                    PL
# siglaUf                                                         MG
# uri              https://dadosabertos.camara.leg.br/api/v2/depu...
# uriPartido       https://dadosabertos.camara.leg.br/api/v2/part...
# urlFoto          https://www.camara.leg.br/internet/deputado/ba...
# Name: 511, dtype: object

# %%
df.tail(1)
# Out:
#                             email      id  idLegislatura         nome  \
# 512  dep.zecadirceu@camara.leg.br  160592             56  ZECA DIRCEU
#
#     siglaPartido siglaUf                                                uri  \
# 512           PT      PR  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                                             uriPartido  \
# 512  https://dadosabertos.camara.leg.br/api/v2/part...
#
#                                                urlFoto
# 512  https://www.camara.leg.br/internet/deputado/ba...

# %%
df.iloc[[0,1,2,511]]
# Out:
#                                email      id  idLegislatura            nome  \
# 0    dep.abiliosantana@camara.leg.br  204554             56  ABÍLIO SANTANA
# 1         dep.abouanni@camara.leg.br  204521             56       ABOU ANNI
# 2    dep.acaciofavacho@camara.leg.br  204379             56  ACÁCIO FAVACHO
# 511        dep.zevitor@camara.leg.br  204517             56        ZÉ VITOR
#
#     siglaPartido siglaUf                                                uri  \
# 0             PL      BA  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1            PSL      SP  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2           PROS      AP  https://dadosabertos.camara.leg.br/api/v2/depu...
# 511           PL      MG  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                                             uriPartido  \
# 0    https://dadosabertos.camara.leg.br/api/v2/part...
# 1    https://dadosabertos.camara.leg.br/api/v2/part...
# ...

# %%
df.iloc[[0,3]]
# Out:
#                              email      id  idLegislatura            nome  \
# 0  dep.abiliosantana@camara.leg.br  204554             56  ABÍLIO SANTANA
# 3    dep.adolfoviana@camara.leg.br  204560             56    ADOLFO VIANA
#
#   siglaPartido siglaUf                                                uri  \
# 0           PL      BA  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3         PSDB      BA  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                                           uriPartido  \
# 0  https://dadosabertos.camara.leg.br/api/v2/part...
# 3  https://dadosabertos.camara.leg.br/api/v2/part...
#
#                                              urlFoto
# 0  https://www.camara.leg.br/internet/deputado/ba...
# 3  https://www.camara.leg.br/internet/deputado/ba...

# %%
lista = range(500,512)

# %%
type(lista)
print(lista)
# Out:
# [500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511]

# %%
list(lista)
# Out:
# [500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511]

# %%
df.iloc[lista]
# Out:
#                                    email      id  idLegislatura  \
# 500         dep.vitorlippi@camara.leg.br  178992             56
# 501    dep.waldenorpereira@camara.leg.br  160569             56
# 502        dep.walteralves@camara.leg.br  178952             56
# 503       dep.welitonprado@camara.leg.br  160518             56
# 504  dep.wellingtonroberto@camara.leg.br   74043             56
# 505     dep.wilsonsantiago@camara.leg.br   74044             56
# 506  dep.wladimirgarotinho@camara.leg.br  204463             56
# 507      dep.wolneyqueiroz@camara.leg.br   74439             56
# 508           dep.zecarlos@camara.leg.br  178889             56
# 509             dep.zeneto@camara.leg.br  204559             56
# 510            dep.zesilva@camara.leg.br  160632             56
# 511            dep.zevitor@camara.leg.br  204517             56
#
#                    nome   siglaPartido siglaUf  \
# 500         VITOR LIPPI           PSDB      SP
# ...

# %%
df.loc[0]
# Out:
# email                              dep.abiliosantana@camara.leg.br
# id                                                          204554
# idLegislatura                                                   56
# nome                                                ABÍLIO SANTANA
# siglaPartido                                                    PL
# siglaUf                                                         BA
# uri              https://dadosabertos.camara.leg.br/api/v2/depu...
# uriPartido       https://dadosabertos.camara.leg.br/api/v2/part...
# urlFoto          https://www.camara.leg.br/internet/deputado/ba...
# Name: 0, dtype: object

# %%
df.loc[511]
# Out:
# email                                    dep.zevitor@camara.leg.br
# id                                                          204517
# idLegislatura                                                   56
# nome                                                      ZÉ VITOR
# siglaPartido                                                    PL
# siglaUf                                                         MG
# uri              https://dadosabertos.camara.leg.br/api/v2/depu...
# uriPartido       https://dadosabertos.camara.leg.br/api/v2/part...
# urlFoto          https://www.camara.leg.br/internet/deputado/ba...
# Name: 511, dtype: object
